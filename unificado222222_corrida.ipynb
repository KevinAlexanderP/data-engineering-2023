# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\kp6948\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\kp6948\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
##Importamos libs
import pandas as pd
import numpy as np
import glob
import os

# %%
df1 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2021EcommerceRaw.csv',encoding='latin-1')
df2 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2022EcommerceRaw.csv',encoding='latin-1')
df3 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2023EcommerceRaw.csv',encoding='latin-1')
all_files = [df1,df2,df3]
df_tier = pd.concat(all_files, ignore_index=True)
# Out:
# C:\Users\kp6948\AppData\Local\Temp\ipykernel_27520\2110018691.py:1: DtypeWarning: Columns (9,10,13,30,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2021EcommerceRaw.csv',encoding='latin-1')
# C:\Users\kp6948\AppData\Local\Temp\ipykernel_27520\2110018691.py:2: DtypeWarning: Columns (8,20,21,22,31,32,55,59,67,69,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2022EcommerceRaw.csv',encoding='latin-1')
# C:\Users\kp6948\AppData\Local\Temp\ipykernel_27520\2110018691.py:3: DtypeWarning: Columns (22,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompleta2023EcommerceRaw.csv',encoding='latin-1')

# %%
df_tier.to_csv(r'C:\Users\\kp6948\Documents\\Carpeta madre nd\\RAW DB\\BDCompletaEcommerceRW.csv')

# %%
df_tier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128309 entries, 0 to 128308
# Data columns (total 71 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   increment_id             128309 non-null  object
#  1   fecha_de_pago            128309 non-null  object
#  2   hora_de_pago             128309 non-null  object
#  3   status                   128309 non-null  object
#  4   tipo                     128309 non-null  object
#  5   numero_renovar           93036 non-null   float64
#  6   f_rpa                    59491 non-null   object
#  7   f_renovacion             53664 non-null   object
#  8   idc                      43980 non-null   object
#  9   crm                      43980 non-null   object
#  10  f_completada             43980 non-null   object
#  11  guest                    128309 non-null  object
#  12  customer_email           128309 non-null  object
# ...

# %%
df =pd.read_csv("C:\\Users\\kp6948\Documents\\thist\\sher poin\\unificado27enero_corrida.csv",encoding='latin-1')
# Out:
# C:\Users\kp6948\AppData\Local\Temp\ipykernel_2392\194783666.py:1: DtypeWarning: Columns (9,10,13,30,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("C:\\Users\\kp6948\Documents\\thist\\sher poin\\Unificado2021.csv",encoding='latin-1')

# %%
# new_equipo = df['equipo'].str.split(pat=r" " ,expand=True  ,n=-1 ,regex=True ).fillna("")

# new_equipo['concat'] = new_equipo[0] + "-" + new_equipo[1] + "-" + new_equipo[2] + "-" +new_equipo[3] + "-" +new_equipo[4]  

# new_equipo['concat'].unique()
# df['equipo'] = new_equipo['concat']

# %%
new_0 = df['mensajeRPA'].str.split(pat=r"[^\\]+(.........[0-9]A)" ,expand=True  ,n=-1 ,regex=True ).fillna("")
new_0[1]





df['ordenmensajeRPA'] = new_0[1]

# %%
new1 = df['crm'].str.split(pat=r"[^\\]+(.........[0-9]A)" ,expand=True ,n=-1 ,regex=True ).fillna("")
new1
df["ordencrm"]= new1[0]

# %%
new2 = df['comentarios'].str.split(pat=r"[^\\]+(.........[0-9]A)" ,expand=True  ,n=-1 ,regex=True ).fillna("")
# new2
df["ordencomentarios"]= new2[1]

# %%
df.head()
# Out:
#    increment_id fecha_de_pago hora_de_pago      status         tipo  \
# 0  ECO000155839    01/01/2021     02:30:23  Completada  RenovaciÃ³n
# 1  ECO000155842    01/01/2021     03:27:13  Completada  RenovaciÃ³n
# 2  ECO000155848    01/01/2021     09:35:20  Completada  RenovaciÃ³n
# 3  ECO000155866    01/01/2021     11:20:26  Completada  RenovaciÃ³n
# 4  ECO000155878    01/01/2021     11:56:15  Completada  RenovaciÃ³n
#
#    numero_renovar  f_rpa  f_renovacion  idc  crm  ...    referencia_evo  \
# 0    5.565767e+09    NaN           NaN  NaN  NaN  ...  eeda3cf9a73449e1
# 1    5.565309e+09    NaN           NaN  NaN  NaN  ...  124932bd64514c74
# 2    2.228292e+09    NaN           NaN  NaN  NaN  ...  bc72e6d75dee45e3
# 3    5.536362e+09    NaN           NaN  NaN  NaN  ...  1ea3e7af95e642a7
# 4    7.222451e+09    NaN           NaN  NaN  NaN  ...  48ebd6d828af4735
#
#   redes_sociales apps_streaming allow_esim addons store_pickup store_address  \
# ...

# %%
df_2 = df[['ordencomentarios','ordenmensajeRPA','ordencrm']]

df_2['Col4'] = df[['ordencomentarios','ordenmensajeRPA','ordencrm']].apply(lambda x: ''.join(x.dropna()), axis=1)
# Out:
# C:\Users\kp6948\AppData\Local\Temp\ipykernel_2392\461919756.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Col4'] = df[['ordencomentarios','ordenmensajeRPA','ordencrm']].apply(lambda x: ''.join(x.dropna()), axis=1)

# %%
df_2
# Out:
#       ordencomentarios ordenmensajeRPA ordencrm                    Col4
# 0          2416172382A     2416172382A           2416172382A2416172382A
# 1          2416180083A     2416180083A           2416180083A2416180083A
# 2          2416290401A     2416290401A           2416290401A2416290401A
# 3          2416327892A     2416327892A           2416327892A2416327892A
# 4          2416339285A     2416339285A           2416339285A2416339285A
# ...                ...             ...      ...                     ...
# 46196      2701991411A                                      2701991411A
# 46197      2701991641A                                      2701991641A
# 46198      2701990924A                                      2701990924A
# 46199      2703650411A                                      2703650411A
# 46200      2702901335A                                      2702901335A
#
# [46201 rows x 4 columns]

# %%
df['ordenfinal'] = df_2['Col4'].str[-11:]
df['Origen'] = "Magento"
df['Fuente'] = "full_bd_unificado"
df['ComentarioDuplicadoECO'] = "No"
df['crm'] = df['ordencrm']

# %%
df.reset_index(drop=True)
# Out:
#        increment_id fecha_de_pago hora_de_pago      status         tipo  \
# 0      ECO000155839    01/01/2021     02:30:23  Completada  RenovaciÃ³n
# 1      ECO000155842    01/01/2021     03:27:13  Completada  RenovaciÃ³n
# 2      ECO000155848    01/01/2021     09:35:20  Completada  RenovaciÃ³n
# 3      ECO000155866    01/01/2021     11:20:26  Completada  RenovaciÃ³n
# 4      ECO000155878    01/01/2021     11:56:15  Completada  RenovaciÃ³n
# ...             ...           ...          ...         ...          ...
# 46196  ECO000469519    31/12/2021     23:40:54  Completada  RenovaciÃ³n
# 46197  ECO000469513    31/12/2021     23:41:57  Completada  RenovaciÃ³n
# 46198  ECO000469522    31/12/2021     23:42:43  Completada  RenovaciÃ³n
# 46199  ECO000469516    31/12/2021     23:43:30  Completada  RenovaciÃ³n
# 46200  ECO000469528    31/12/2021     23:51:35  Completada  RenovaciÃ³n
#
#        numero_renovar  f_rpa  f_renovacion  idc crm  ... addons store_pickup  \
# ...

# %%
a_index= ['increment_id',
 'fecha_de_pago',
 'status',
 'tipo',
 'guest',
 'region_factura',
 'oferta',
 'paquete',
 'mesesservicio',
 'sku',
 'precio_equipo',
 'precio_plan',
 'qty_ordered',
 'activacion',
 'total_pedido',
 'payment_method',
 'brand',
 'crm',
 'Origen',
 'Fuente',
 'ComentarioDuplicadoECO',
 'ordenmensajeRPA',
 'ordencrm',
 'ordencomentarios',
 'ordenfinal',
 'allow_esim']
df = df[a_index]

df.reindex(columns=[a_index])


df.to_csv(r'C:\\Users\\kp6948\Documents\\thist\\corridas\\unificado27enero_corrida_clean.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46201 entries, 0 to 46200
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   increment_id            46201 non-null  object
#  1   fecha_de_pago           46201 non-null  object
#  2   status                  46201 non-null  object
#  3   tipo                    46201 non-null  object
#  4   guest                   46201 non-null  object
#  5   region_factura          46201 non-null  object
#  6   oferta                  46201 non-null  object
#  7   paquete                 26669 non-null  object
#  8   mesesservicio           26579 non-null  object
#  9   sku                     19730 non-null  object
#  10  precio_equipo           19532 non-null  object
#  11  precio_plan             1093 non-null   float64
#  12  qty_ordered             46201 non-null  int64
#  13  activacion              1093 non-null   float64
# ...

# %%
df_subido_head = pd.read_csv('C:\\Users\\kp6948\\Downloads\\df_axyys prueba sincols2.csv')
list(df_subido_head.columns.values)
# Out:
# ['increment_id',
#  'fecha_de_pago',
#  'status',
#  'tipo',
#  'guest',
#  'region_factura',
#  'oferta',
#  'paquete',
#  'mesesservicio',
#  'sku',
#  'precio_equipo',
#  'precio_plan',
#  'qty_ordered',
#  'activacion',
#  'total_pedido',
#  'payment_method',
#  'brand',
#  'crm',
#  'Origen',
#  'Fuente',
#  'ComentarioDuplicadoECO',
#  'ordenmensajeRPA',
#  'ordencrm',
#  'ordencomentarios',
#  'ordenfinal',
#  'allow_esim']
