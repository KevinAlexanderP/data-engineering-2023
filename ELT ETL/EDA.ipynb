# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect("postgresql://dwhuser:Passw0rd@dwhcluster.cmlgzkqndwze.us-west-2.redshift.amazonaws.com:5439/dwh")
cur = conn.cursor()

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT COUNT(*)
FROM users;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (104,)

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT COUNT(*)
FROM songs;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (14896,)

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT COUNT(*)
FROM artists;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (10025,)

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT COUNT(*)
FROM time;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (6813,)

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT COUNT(*)
FROM songplays;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (9957,)

# %%
try:
      # retrieving all tables in my search_path
      cur.execute("""SELECT  sp.songplay_id,
        u.user_id,
        u.last_name,
        u.first_name,
        sp.start_time,
        a.name,
        s.title
FROM songplays AS sp
        JOIN users   AS u ON (u.user_id = sp.user_id)
        JOIN songs   AS s ON (s.song_id = sp.song_id)
        JOIN artists AS a ON (a.artist_id = sp.artist_id)
        JOIN time    AS t ON (t.start_time = sp.start_time)
ORDER BY (u.last_name)
LIMIT 100;""")
except Exception as err:
      print(err.code,err)

rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (2718, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'The Older I Get [Acoustic]')
# (8522, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 5, 56, 58), 'The Cinematic Orchestra/London Metropolitan Orchestra', 'Dawn')
# (1065, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter', 'Why')
# (3314, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter feat. DJ Mental Theos Bazzheadz', 'Every Morning')
# (1065, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter feat. DJ Mental Theos Bazzheadz', 'Why')
# (2826, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'El Maximo Daño')
# (8476, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 7, 25), 'Great Lake Swimmers', "River's Edge")
# (3294, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 41, 9), 'Devin Townsend', 'Hidden Track')
# (8016, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Suncanom stranom')
# (8522, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 5, 56, 58), 'The Cinematic Orchestra', 'Dawn')
# (419, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 0, 40, 37), 'Fu', 'To Wszystko Co Mam')
# (4124, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Overdrive')
# (3127, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Rumore')
# (3294, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 41, 9), 'Townsend_ Devin', 'Hidden Track')
# (3825, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Maid')
# (2447, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Looking For Angels (Album Version)')
# (8133, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Zastave')
# (6168, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Mama Kin')
# (248, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 19, 10, 42), 'Evanescence', 'Missing (Live in Europe)')
# (917, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 13, 32, 59), 'Eric B. & Rakim', 'Follow The Leader')
# (4400, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Autentico')
# (4375, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Suspended')
# (1823, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 0, 40, 37), 'Fu', 'Nie Mów Mi')
# (824, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Wicker Chair')
# (3314, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter', 'Every Morning')
# (3119, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Mezquindad')
# (2834, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 29, 30), 'Flaw', 'Endangered Species')
# (3913, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'God Smack')
# (1382, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 6, 9, 6), 'Viola', 'My Troubled One')
# (9814, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 21, 13, 57, 53), 'Rick James', 'Mr. Policeman')
# (6160, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Locomotive (Complicity)')
# (8075, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 42, 32), 'Smash Mouth', 'Nervous In The Alley')
# (4165, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Hell')
# (816, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Genius')
# (920, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 10, 12, 44, 10), 'Juanes', 'Rebelion')
# (7297, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Dok je tebe')
# (4157, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'If Ever')
# (2439, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Would It Matter (Bonus Track)')
# (2258, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Energy (Album Version)')
# (4069, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 9, 30), 'Lily Allen', 'U Killed It')
# (4519, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'X-Static')
# (7678, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 14, 24), 'Franz Ferdinand', 'Do You Want To')
# (9676, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 21, 13, 57, 53), 'Rick James', 'She Blew My Mind (69 Times)')
# (4092, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'Brother')
# (4812, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 17, 16), 'Modest Mouse', 'The Whale Song')
# (247, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Day Old Blues')
# (3917, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 50, 45), 'Talking Heads', 'Two Note Swivel (Unfinished Outtake)')
# (3719, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 31, 32), 'Benga', 'Zero M2')
# (2818, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Va Bien')
# (3987, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Next Year')
# (8439, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Oba lica ljubavi')
# (5022, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Catcher In The Rye')
# (5788, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", "You're Crazy")
# (3396, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Little Victories')
# (2280, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Rebirthing (Album Version)')
# (1882, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Ragoo')
# (5306, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Still')
# (3404, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 9, 30), 'Lily Allen', 'LDN (Warbox Original Cut Dub)')
# (4760, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'Lesson Learned')
# (1285, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 8, 43), 'Eminem', 'Ricky Ticky Toc')
# (740, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 8, 43), 'Eminem', "I'm Back")
# (4723, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Fake Plastic Trees (Acoustic Version)')
# (3846, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Vegetable (Live)')
# (4434, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Fast-Track')
# (4739, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Pop Is Dead')
# (3361, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Subterranean Homesick Alien')
# (134, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'Street Lights')
# (1259, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 4, 36), 'Interpol', 'Wrecking Ball')
# (4677, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Bullet Proof ... I Wish I Was (Acoustic)')
# (3854, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', '15 Step')
# (5030, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 11, 26), 'Lupe Fiasco', 'Streets On Fire (Explicit Album Version)')
# (381, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'Skit #2 (Kanye West/Late Registration)')
# (5030, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 11, 26), 'Lupe Fiasco feat. Matthew Santos', 'Streets On Fire (Explicit Album Version)')
# (4731, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Stop Whispering (US Version)')
# (1786, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'School Spirit Skit 2')
# (1992, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'Ionized')
# (4050, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'Power Gen')
# (6267, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 4, 0, 50, 3), 'Professor Longhair', 'No Buts - No Maybes')
# (1975, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'People Can Fly')
# (8268, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 29, 15), 'Hot Chip', 'Hold On')
# (7715, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 57, 29), 'Linkin Park', 'Crawling (Album Version)')
# (3090, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', '730 dias (Cara B)')
# (2791, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 9, 17, 17, 1), 'Linkin Park', 'Crawling (Album Version)')
# (995, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'Heaven Only Knows')
# (6189, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 28, 10, 48, 46), 'Concrete Blonde', 'Joey (Acoustic) (Live)')
# (7104, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'Speed Of Sound (Live)')
# (8509, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 9, 17, 17, 1), 'Linkin Park', 'Given Up (Album Version)')
# (7120, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'One I Love')
# (3098, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'Camino A La Paloma')
# (8364, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'Soledad')
# (6036, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 28, 10, 48, 46), 'Concrete Blonde', 'Valentine')
# (2469, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'B-Boy Stance')
# (6038, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'A Rush Of Blood To The Head (Live In Sydney)')
# (8383, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 7, 7, 58, 28), 'Jagged Edge', "Let's Get Married")
# (402, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'Clap Ur Handz')
# (8589, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'No Pienses De Mas')
# (7774, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 57, 29), 'Linkin Park', 'Given Up (Album Version)')
# (8342, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 4, 16, 23, 7), 'Shaggy', 'Criteria')
# (2014, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 20, 15, 50, 1), 'Lonnie Gordon', 'Catch You Baby (Wideboys Electro Remix)')
# (8383, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 7, 7, 58, 28), 'Jagged Edge featuring Run of Run DMC', "Let's Get Married")

# %%
with conn:
    sql = """SELECT  sp.songplay_id,
        u.user_id,
        u.last_name,
        u.first_name,
        sp.start_time,
        a.name,
        s.title
FROM songplays AS sp
        JOIN users   AS u ON (u.user_id = sp.user_id)
        JOIN songs   AS s ON (s.song_id = sp.song_id)
        JOIN artists AS a ON (a.artist_id = sp.artist_id)
        JOIN time    AS t ON (t.start_time = sp.start_time)
ORDER BY (u.last_name)
LIMIT 100;"""
    dat = pd.read_sql_query(sql, conn)

dat
# Out:
#     songplay_id  user_id last_name first_name          start_time  \
# 0          6123       66  Arellano      Kevin 2018-11-13 00:40:37
# 1          2066       66  Arellano      Kevin 2018-11-23 00:11:00
# 2          6840       66  Arellano      Kevin 2018-11-23 00:25:11
# 3          9570       66  Arellano      Kevin 2018-11-23 05:56:58
# 4          5630       66  Arellano      Kevin 2018-11-02 02:42:48
# 5          3488       66  Arellano      Kevin 2018-11-12 19:10:42
# 6          5977       66  Arellano      Kevin 2018-11-06 07:36:46
# 7          6698       66  Arellano      Kevin 2018-11-06 07:36:46
# 8          1364       66  Arellano      Kevin 2018-11-23 00:07:25
# 9          8809       66  Arellano      Kevin 2018-11-27 04:48:07
# 10         9615       66  Arellano      Kevin 2018-11-07 12:06:23
# 11         9054       66  Arellano      Kevin 2018-11-12 11:41:09
# 12         1807       66  Arellano      Kevin 2018-11-23 00:11:00
# 13         9570       66  Arellano      Kevin 2018-11-23 05:56:58
# 14         5977       66  Arellano      Kevin 2018-11-06 07:36:46
# 15         5852       66  Arellano      Kevin 2018-11-23 00:33:55
# 16         7021       66  Arellano      Kevin 2018-11-23 00:25:11
# 17         8798       66  Arellano      Kevin 2018-11-21 13:57:53
# 18         5911       66  Arellano      Kevin 2018-11-02 02:42:48
# 19         1799       66  Arellano      Kevin 2018-11-23 00:11:00
# 20         5192       66  Arellano      Kevin 2018-11-06 07:39:56
# 21         9054       66  Arellano      Kevin 2018-11-12 11:41:09
# 22         5547       66  Arellano      Kevin 2018-11-23 00:42:32
# 23         1696       66  Arellano      Kevin 2018-11-23 00:11:00
# 24         8993       66  Arellano      Kevin 2018-11-07 12:06:23
# 25         6680       66  Arellano      Kevin 2018-11-10 12:44:10
# 26         2378       66  Arellano      Kevin 2018-11-23 00:29:30
# 27         6698       66  Arellano      Kevin 2018-11-06 07:36:46
# 28         3398       66  Arellano      Kevin 2018-11-23 06:09:06
# 29         6021       66  Arellano      Kevin 2018-11-23 00:33:55
# ..          ...      ...       ...        ...                 ...
# 70         1654       34     Ayala     Evelin 2018-11-14 13:11:26
# 71         9349       34     Ayala     Evelin 2018-11-06 14:59:25
# 72         1654       34     Ayala     Evelin 2018-11-14 13:11:26
# 73         1875       34     Ayala     Evelin 2018-11-14 13:07:11
# 74         1957       34     Ayala     Evelin 2018-11-14 13:07:11
# 75         6136       99     Banks        Ann 2018-11-09 15:33:05
# 76         6386       99     Banks        Ann 2018-11-09 15:33:05
# 77         1284       99     Banks        Ann 2018-11-09 15:29:15
# 78         6455       99     Banks        Ann 2018-11-09 15:33:05
# 79         7067       99     Banks        Ann 2018-11-04 00:50:03
# 80          703      100   Barrera      Adler 2018-11-09 17:17:01
# 81         1498      100   Barrera      Adler 2018-11-02 13:25:38
# 82         2763      100   Barrera      Adler 2018-11-14 15:57:29
# 83          635      100   Barrera      Adler 2018-11-12 08:58:41
# 84         4728      100   Barrera      Adler 2018-11-14 15:52:11
# 85          941      100   Barrera      Adler 2018-11-12 08:58:41
# 86          922      100   Barrera      Adler 2018-11-12 08:58:41
# 87         1813      100   Barrera      Adler 2018-11-28 10:48:46
# 88         1506      100   Barrera      Adler 2018-11-02 13:25:38
# 89         2398      100   Barrera      Adler 2018-11-14 15:57:29
# 90         1740      100   Barrera      Adler 2018-11-28 10:48:46
# 91         4712      100   Barrera      Adler 2018-11-14 15:52:11
# 92         4262      100   Barrera      Adler 2018-11-14 15:52:11
# 93         6959      100   Barrera      Adler 2018-11-07 07:58:28
# 94           86      100   Barrera      Adler 2018-11-20 15:50:01
# 95          361      100   Barrera      Adler 2018-11-04 16:18:48
# 96         1029      100   Barrera      Adler 2018-11-09 17:17:01
# 97         4742      100   Barrera      Adler 2018-11-04 16:23:07
# 98         1468      100   Barrera      Adler 2018-11-02 13:25:38
# 99          627      100   Barrera      Adler 2018-11-12 08:58:41
#
#                                                  name  \
# 0                                                  Fu
# 1                                 Soziedad Alkoholika
# 2                                        Parni Valjak
# 3   The Cinematic Orchestra/London Metropolitan Or...
# 4                                             Skillet
# 5                                         Evanescence
# 6          Basshunter feat. DJ Mental Theos Bazzheadz
# 7          Basshunter feat. DJ Mental Theos Bazzheadz
# 8                                 Great Lake Swimmers
# 9                                     Alice In Chains
# 10                                     Matt Nathanson
# 11                                     Devin Townsend
# 12                                Soziedad Alkoholika
# 13                            The Cinematic Orchestra
# 14                                         Basshunter
# 15                                       Foo Fighters
# 16                                       Parni Valjak
# 17                                         Rick James
# 18                                            Skillet
# 19                                Soziedad Alkoholika
# 20                                      Kings Of Leon
# 21                                    Townsend_ Devin
# 22                                        Smash Mouth
# 23                                Soziedad Alkoholika
# 24                                     Matt Nathanson
# 25                                             Juanes
# 26                                               Flaw
# 27                                         Basshunter
# 28                                              Viola
# 29                                       Foo Fighters
# ..                                                ...
# 70                   Lupe Fiasco feat. Matthew Santos
# 71                                         Kanye West
# 72                                        Lupe Fiasco
# 73                                          Radiohead
# 74                                          Radiohead
# 75                                  Astral Projection
# 76                                  Astral Projection
# 77                                           Hot Chip
# 78                                  Astral Projection
# 79                                 Professor Longhair
# 80                                        Linkin Park
# 81                                      Jorge Drexler
# 82                                        Linkin Park
# 83                                               K-OS
# 84                                           Coldplay
# 85                                               K-OS
# 86                                               K-OS
# 87                                    Concrete Blonde
# 88                                      Jorge Drexler
# 89                                        Linkin Park
# 90                                    Concrete Blonde
# 91                                           Coldplay
# 92                                           Coldplay
# 93                                        Jagged Edge
# 94                                      Lonnie Gordon
# 95                                      Finger Eleven
# 96                                        Linkin Park
# 97                                             Shaggy
# 98                                      Jorge Drexler
# 99                                               K-OS
#
#                                            title
# 0                             To Wszystko Co Mam
# 1                                 El Maximo Daño
# 2                               Suncanom stranom
# 3                                           Dawn
# 4                     The Older I Get [Acoustic]
# 5                       Missing (Live in Europe)
# 6                                            Why
# 7                                  Every Morning
# 8                                   River's Edge
# 9                                      God Smack
# 10                                     Suspended
# 11                                  Hidden Track
# 12                                        Rumore
# 13                                          Dawn
# 14                                           Why
# 15                                     Overdrive
# 16                                       Zastave
# 17                                 Mr. Policeman
# 18            Looking For Angels (Album Version)
# 19                                    Mezquindad
# 20                                  Wicker Chair
# 21                                  Hidden Track
# 22                          Nervous In The Alley
# 23                                     Autentico
# 24                                          Maid
# 25                                      Rebelion
# 26                            Endangered Species
# 27                                 Every Morning
# 28                               My Troubled One
# 29                                          Hell
# ..                                           ...
# 70      Streets On Fire (Explicit Album Version)
# 71        Skit #2 (Kanye West/Late Registration)
# 72      Streets On Fire (Explicit Album Version)
# 73                  Stop Whispering (US Version)
# 74      Bullet Proof ... I Wish I Was (Acoustic)
# 75                                       Ionized
# 76                                     Power Gen
# 77                                       Hold On
# 78                                People Can Fly
# 79                           No Buts - No Maybes
# 80                      Crawling (Album Version)
# 81                             730 dias (Cara B)
# 82                      Crawling (Album Version)
# 83                             Heaven Only Knows
# 84                                    One I Love
# 85                                  B-Boy Stance
# 86                                 Clap Ur Handz
# 87                        Joey (Acoustic) (Live)
# 88                            Camino A La Paloma
# 89                      Given Up (Album Version)
# 90                                     Valentine
# 91                         Speed Of Sound (Live)
# 92  A Rush Of Blood To The Head (Live In Sydney)
# 93                             Let's Get Married
# 94       Catch You Baby (Wideboys Electro Remix)
# 95                                           Tip
# 96                      Given Up (Album Version)
# 97                                      Criteria
# 98                                       Soledad
# 99                              Man I Used To Be
#
# [100 rows x 7 columns]
